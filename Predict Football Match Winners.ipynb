# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 1  2023-08-11  20:00  Premier League  Matchweek 1  Fri  Away      W  3.0  0.0
# 3  2023-08-19  20:00  Premier League  Matchweek 2  Sat  Home      W  1.0  0.0
# 4  2023-08-27  14:00  Premier League  Matchweek 3  Sun  Away      W  2.0  1.0
# 5  2023-09-02  15:00  Premier League  Matchweek 4  Sat  Home      W  5.0  1.0
# 6  2023-09-16  15:00  Premier League  Matchweek 5  Sat  Away      W  3.0  1.0
#
#         Opponent  ...  Match Report  Notes    Sh   SoT  Dist   FK   PK PKatt  \
# 1        Burnley  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0.0   0.0
# 3  Newcastle Utd  ...  Match Report    NaN  14.0   4.0  17.9  0.0  0.0   0.0
# 4  Sheffield Utd  ...  Match Report    NaN  29.0   9.0  17.3  2.0  0.0   1.0
# 5         Fulham  ...  Match Report    NaN   6.0   4.0  14.8  0.0  1.0   1.0
# 6       West Ham  ...  Match Report    NaN  29.0  13.0  16.4  1.0  0.0   0.0
#
#    Season             Team
# 1    2023  Manchester City
# 3    2023  Manchester City
# 4    2023  Manchester City
# 5    2023  Manchester City
# 6    2023  Manchester City
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (2072, 27)

# %%
matches.dtypes
# Out:
# Date             object
# Time             object
# Comp             object
# Round            object
# Day              object
# Venue            object
# Result           object
# GF              float64
# GA              float64
# Opponent         object
# xG              float64
# xGA             float64
# Poss            float64
# Attendance      float64
# Captain          object
# Formation        object
# Referee          object
# Match Report     object
# Notes           float64
# Sh              float64
# SoT             float64
# Dist            float64
# FK              float64
# PK              float64
# PKatt           float64
# Season            int64
# Team             object
# dtype: object

# %%
matches["Date"] = pd.to_datetime(matches["Date"])

# %%
matches["venue_code"] = matches["Venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["Opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["Time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["Date"].dt.dayofweek

# %%
matches["target"] = (matches["Result"] == "W").astype("int")

# %%
matches
# Out:
#          Date   Time            Comp         Round  Day Venue Result   GF  \
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W  3.0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W  1.0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2.0
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5.0
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      GA        Opponent  ...   FK   PK  PKatt  Season              Team  \
# 1   0.0         Burnley  ...  0.0  0.0    0.0    2023   Manchester City
# 3   0.0   Newcastle Utd  ...  0.0  0.0    0.0    2023   Manchester City
# 4   1.0   Sheffield Utd  ...  2.0  0.0    1.0    2023   Manchester City
# 5   1.0          Fulham  ...  0.0  1.0    1.0    2023   Manchester City
# 6   1.0        West Ham  ...  1.0  0.0    0.0    2023   Manchester City
# ..  ...             ...  ...  ...  ...    ...     ...               ...
# 38  4.0       Tottenham  ...  0.0  0.0    0.0    2022  Sheffield United
# 39  2.0  Crystal Palace  ...  1.0  0.0    0.0    2022  Sheffield United
# 40  0.0         Everton  ...  0.0  0.0    0.0    2022  Sheffield United
# 41  1.0   Newcastle Utd  ...  1.0  0.0    0.0    2022  Sheffield United
# 42  0.0         Burnley  ...  0.0  0.0    0.0    2022  Sheffield United
#
#    venue_code opp_code hour  day_code  target
# 1           0        5   20         4       1
# 3           1       16   20         5       1
# 4           0       19   14         6       1
# 5           1        9   15         5       1
# 6           0       24   15         5       1
# ..        ...      ...  ...       ...     ...
# 38          0       21   19         6       0
# 39          1        7   15         5       0
# 40          0        8   19         6       1
# 41          0       16   18         2       0
# 42          1        5   16         6       1
#
# [2072 rows x 32 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["Date"] < '2023-01-01']

# %%
test = matches[matches["Date"] > '2023-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.5876010781671159

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           157  41
# 1           112  61

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.5980392156862745

# %%
grouped_matches = matches.groupby("Team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("Date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("Date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["GF", "GA", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['GF_rolling',
#  'GA_rolling',
#  'Sh_rolling',
#  'SoT_rolling',
#  'Dist_rolling',
#  'FK_rolling',
#  'PK_rolling',
#  'PKatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 5  2020-10-17  17:30  Premier League  Matchweek 5  Sat  Home      W  1.0  0.0
# 7  2020-10-24  12:30  Premier League  Matchweek 6  Sat  Away      D  1.0  1.0
# 9  2020-10-31  12:30  Premier League  Matchweek 7  Sat  Away      W  1.0  0.0
# 11 2020-11-08  16:30  Premier League  Matchweek 8  Sun  Home      D  1.0  1.0
# 12 2020-11-21  17:30  Premier League  Matchweek 9  Sat  Away      L  0.0  2.0
# ..        ...    ...             ...          ...  ...   ...    ...  ...  ...
# 4  2023-08-27  14:00  Premier League  Matchweek 3  Sun  Away      W  2.0  1.0
# 5  2023-09-02  15:00  Premier League  Matchweek 4  Sat  Home      W  5.0  1.0
# 6  2023-09-16  15:00  Premier League  Matchweek 5  Sat  Away      W  3.0  1.0
# 8  2023-09-23  15:00  Premier League  Matchweek 6  Sat  Home      W  2.0  0.0
# 10 2023-09-30  15:00  Premier League  Matchweek 7  Sat  Away      L  1.0  2.0
#
#            Opponent  ...  day_code  target  GF_rolling  GA_rolling Sh_rolling  \
# 5           Arsenal  ...         5       1    2.000000    2.333333  17.333333
# 7          West Ham  ...         5       0    1.333333    2.000000  17.333333
# 9     Sheffield Utd  ...         5       1    1.000000    0.666667  16.666667
# 11        Liverpool  ...         6       0    1.000000    0.333333  14.333333
# 12        Tottenham  ...         5       0    1.000000    0.666667  12.000000
# ..              ...  ...       ...     ...         ...         ...        ...
# 4     Sheffield Utd  ...         6       1    1.333333    0.333333  16.000000
# 5            Fulham  ...         5       1    2.000000    0.333333  20.000000
# 6          West Ham  ...         5       1    2.666667    0.666667  16.333333
# 8   Nott'ham Forest  ...         5       1    3.333333    1.000000  21.333333
# 10           Wolves  ...         5       0    3.333333    0.666667  14.000000
#
#    SoT_rolling Dist_rolling FK_rolling  PK_rolling  PKatt_rolling
# 5     4.666667    19.700000   1.333333    0.333333       0.333333
# 7     3.666667    18.566667   0.666667    0.000000       0.000000
# 9     4.333333    18.933333   0.666667    0.000000       0.000000
# 11    6.666667    19.033333   1.000000    0.000000       0.000000
# 12    5.666667    20.000000   1.000000    0.000000       0.333333
# ..         ...          ...        ...         ...            ...
# 4     4.666667    16.200000   0.000000    0.000000       0.000000
# 5     7.000000    16.366667   0.666667    0.000000       0.333333
# 6     5.666667    16.666667   0.666667    0.333333       0.666667
# 8     8.666667    16.166667   1.000000    0.333333       0.666667
# 10    7.000000    16.133333   1.000000    0.333333       0.333333
#
# [118 rows x 40 columns]

# %%
del matches["Comp"]

# %%
del matches["Notes"]

# %%
matches_rolling = matches.groupby("Team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  Date   Time        Round  Day Venue Result  \
# Team
# Arsenal                 6  2020-10-04  14:00  Matchweek 4  Sun  Home      W
#                         7  2020-10-17  17:30  Matchweek 5  Sat  Away      L
#                         9  2020-10-25  19:15  Matchweek 6  Sun  Home      L
#                         11 2020-11-01  16:30  Matchweek 7  Sun  Away      W
#                         13 2020-11-08  19:15  Matchweek 8  Sun  Home      L
# ...                               ...    ...          ...  ...   ...    ...
# Wolverhampton Wanderers 2  2023-08-26  15:00  Matchweek 3  Sat  Away      W
#                         4  2023-09-03  14:00  Matchweek 4  Sun  Away      L
#                         5  2023-09-16  12:30  Matchweek 5  Sat  Home      L
#                         6  2023-09-23  15:00  Matchweek 6  Sat  Away      D
#                         8  2023-09-30  15:00  Matchweek 7  Sat  Home      W
#
#                              GF   GA         Opponent   xG  ...  day_code  \
# Team                                                        ...
# Arsenal                 6   2.0  1.0    Sheffield Utd  0.6  ...         6
#                         7   0.0  1.0  Manchester City  0.9  ...         5
#                         9   0.0  1.0   Leicester City  0.7  ...         6
#                         11  1.0  0.0   Manchester Utd  1.0  ...         6
#                         13  0.0  3.0      Aston Villa  1.5  ...         6
# ...                         ...  ...              ...  ...  ...       ...
# Wolverhampton Wanderers 2   1.0  0.0          Everton  1.1  ...         5
#                         4   2.0  3.0   Crystal Palace  1.2  ...         6
#                         5   1.0  3.0        Liverpool  0.6  ...         5
#                         6   1.0  1.0       Luton Town  0.6  ...         5
#                         8   2.0  1.0  Manchester City  0.4  ...         5
#
#                             target  GF_rolling GA_rolling Sh_rolling  \
# Team
# Arsenal                 6        1    2.000000   1.333333   8.000000
#                         7        0    1.666667   1.666667   5.666667
#                         9        0    1.000000   1.666667   7.000000
#                         11       1    0.666667   1.000000   9.666667
#                         13       0    0.333333   0.666667   9.666667
# ...                            ...         ...        ...        ...
# Wolverhampton Wanderers 2        1    0.666667   2.666667  15.333333
#                         4        0    0.666667   1.666667  16.666667
#                         5        0    1.333333   2.333333  13.000000
#                         6        0    1.333333   2.000000  11.333333
#                         8        1    1.333333   2.333333   8.666667
#
#                            SoT_rolling Dist_rolling  FK_rolling  PK_rolling  \
# Team
# Arsenal                 6     3.666667    14.633333    0.666667    0.000000
#                         7     3.666667    15.366667    0.000000    0.000000
#                         9     3.666667    16.566667    0.666667    0.000000
#                         11    4.000000    16.566667    1.000000    0.000000
#                         13    2.666667    19.333333    1.000000    0.333333
# ...                                ...          ...         ...         ...
# Wolverhampton Wanderers 2     5.333333    15.366667    0.000000    0.000000
#                         4     4.333333    16.400000    0.333333    0.000000
#                         5     3.666667    16.700000    0.333333    0.000000
#                         6     2.666667    17.566667    0.333333    0.000000
#                         8     3.000000    13.966667    0.000000    0.000000
#
#                             PKatt_rolling
# Team
# Arsenal                 6        0.000000
#                         7        0.000000
#                         9        0.000000
#                         11       0.000000
#                         13       0.333333
# ...                                   ...
# Wolverhampton Wanderers 2        0.000000
#                         4        0.000000
#                         5        0.000000
#                         6        0.000000
#                         8        0.000000
#
# [1991 rows x 38 columns]

# %%
matches_rolling = matches_rolling.droplevel('Team')

# %%
matches_rolling
# Out:
#          Date   Time        Round  Day Venue Result   GF   GA  \
# 6  2020-10-04  14:00  Matchweek 4  Sun  Home      W  2.0  1.0
# 7  2020-10-17  17:30  Matchweek 5  Sat  Away      L  0.0  1.0
# 9  2020-10-25  19:15  Matchweek 6  Sun  Home      L  0.0  1.0
# 11 2020-11-01  16:30  Matchweek 7  Sun  Away      W  1.0  0.0
# 13 2020-11-08  19:15  Matchweek 8  Sun  Home      L  0.0  3.0
# ..        ...    ...          ...  ...   ...    ...  ...  ...
# 2  2023-08-26  15:00  Matchweek 3  Sat  Away      W  1.0  0.0
# 4  2023-09-03  14:00  Matchweek 4  Sun  Away      L  2.0  3.0
# 5  2023-09-16  12:30  Matchweek 5  Sat  Home      L  1.0  3.0
# 6  2023-09-23  15:00  Matchweek 6  Sat  Away      D  1.0  1.0
# 8  2023-09-30  15:00  Matchweek 7  Sat  Home      W  2.0  1.0
#
#            Opponent   xG  ...  day_code  target  GF_rolling GA_rolling  \
# 6     Sheffield Utd  0.6  ...         6       1    2.000000   1.333333
# 7   Manchester City  0.9  ...         5       0    1.666667   1.666667
# 9    Leicester City  0.7  ...         6       0    1.000000   1.666667
# 11   Manchester Utd  1.0  ...         6       1    0.666667   1.000000
# 13      Aston Villa  1.5  ...         6       0    0.333333   0.666667
# ..              ...  ...  ...       ...     ...         ...        ...
# 2           Everton  1.1  ...         5       1    0.666667   2.666667
# 4    Crystal Palace  1.2  ...         6       0    0.666667   1.666667
# 5         Liverpool  0.6  ...         5       0    1.333333   2.333333
# 6        Luton Town  0.6  ...         5       0    1.333333   2.000000
# 8   Manchester City  0.4  ...         5       1    1.333333   2.333333
#
#    Sh_rolling SoT_rolling Dist_rolling  FK_rolling  PK_rolling  PKatt_rolling
# 6    8.000000    3.666667    14.633333    0.666667    0.000000       0.000000
# 7    5.666667    3.666667    15.366667    0.000000    0.000000       0.000000
# 9    7.000000    3.666667    16.566667    0.666667    0.000000       0.000000
# 11   9.666667    4.000000    16.566667    1.000000    0.000000       0.000000
# 13   9.666667    2.666667    19.333333    1.000000    0.333333       0.333333
# ..        ...         ...          ...         ...         ...            ...
# 2   15.333333    5.333333    15.366667    0.000000    0.000000       0.000000
# 4   16.666667    4.333333    16.400000    0.333333    0.000000       0.000000
# 5   13.000000    3.666667    16.700000    0.333333    0.000000       0.000000
# 6   11.333333    2.666667    17.566667    0.333333    0.000000       0.000000
# 8    8.666667    3.000000    13.966667    0.000000    0.000000       0.000000
#
# [1991 rows x 38 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["Date"] < '2023-01-01']
    test = data[data["Date"] > '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5648854961832062

# %%
combined = combined.merge(matches_rolling[["Date", "Team", "Opponent", "Result"]], left_index=True, right_index=True)

# %%
combined.head()
# Out:
#     actual  predicted       Date     Team        Opponent Result
# 89       0          1 2023-01-03  Arsenal   Newcastle Utd      D
# 90       1          1 2023-01-15  Arsenal       Tottenham      W
# 91       1          0 2023-01-22  Arsenal  Manchester Utd      W
# 92       0          1 2023-02-04  Arsenal         Everton      L
# 93       0          1 2023-02-11  Arsenal       Brentford      D

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["Team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["Date", "new_team"], right_on=["Date", "Opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       Date                   Team_x  \
# 0           0            1 2023-01-03                  Arsenal
# 1           1            1 2023-01-15                  Arsenal
# 2           1            0 2023-01-22                  Arsenal
# 3           0            1 2023-02-11                  Arsenal
# 4           0            0 2023-02-15                  Arsenal
# ..        ...          ...        ...                      ...
# 226         1            0 2023-08-26  Wolverhampton Wanderers
# 227         0            0 2023-09-03  Wolverhampton Wanderers
# 228         0            0 2023-09-16  Wolverhampton Wanderers
# 229         0            0 2023-09-23  Wolverhampton Wanderers
# 230         1            0 2023-09-30  Wolverhampton Wanderers
#
#           Opponent_x Result_x new_team_x  actual_y  predicted_y  \
# 0      Newcastle Utd        D    Arsenal         0            0
# 1          Tottenham        W    Arsenal         0            0
# 2     Manchester Utd        W    Arsenal         0            1
# 3          Brentford        D    Arsenal         0            1
# 4    Manchester City        L    Arsenal         1            1
# ..               ...      ...        ...       ...          ...
# 226          Everton        W     Wolves         0            0
# 227   Crystal Palace        L     Wolves         1            1
# 228        Liverpool        L     Wolves         1            1
# 229       Luton Town        D     Wolves         0            0
# 230  Manchester City        W     Wolves         0            0
#
#                 Team_y Opponent_y Result_y       new_team_y
# 0     Newcastle United    Arsenal        D    Newcastle Utd
# 1    Tottenham Hotspur    Arsenal        L        Tottenham
# 2    Manchester United    Arsenal        L   Manchester Utd
# 3            Brentford    Arsenal        D        Brentford
# 4      Manchester City    Arsenal        W  Manchester City
# ..                 ...        ...      ...              ...
# 226            Everton     Wolves        L          Everton
# 227     Crystal Palace     Wolves        W   Crystal Palace
# 228          Liverpool     Wolves        W        Liverpool
# 229         Luton Town     Wolves        D       Luton Town
# 230    Manchester City     Wolves        L  Manchester City
#
# [231 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    31
# 0    27
# Name: actual_x, dtype: int64

# %%
31 / 58
# Out:
# 0.5344827586206896

# %%
# add more data(season)
